# %%
import seaborn as sns
df = sns.load_dataset('tips')
# for continuous data,we should use jointplot,pairplot,distplot
# for categorical data,we should use boxplot,violinplot,countplot,barplot

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
df.corr(method='spearman')
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.678968  0.604791
# tip           0.678968  1.000000  0.468268
# size          0.604791  0.468268  1.000000

# %%
sns.heatmap(df.corr(method='spearman'))

# %%
# univariate analysis
# jointplot
sns.jointplot(x='tip',y='total_bill',data=df,kind='scatter')

# %%
# paiplot
sns.pairplot(df)

# %%
sns.pairplot(df,hue='sex')

# %%
# distplot works as histogram
sns.distplot(df['tip'])

# %%
# countplot
sns.countplot(df['sex'])

# %%
sns.barplot(df['total_bill'],df['sex'])

# %%
# boxplot
sns.boxplot(df['sex'],df['total_bill'])

# %%
sns.boxplot(df['day'],df['total_bill'],hue=df['smoker'])

# %%
sns.violinplot(df['day'],df['total_bill'],pal)
